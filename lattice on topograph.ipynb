# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nx=11
ny=10
v1 = [-0.465, -0.179]
v2 = [-0.0256,-0.486]

# %%
x = np.meshgrid(np.arange(nx),np.arange(nx))
y = np.meshgrid(np.arange(ny),np.arange(ny))
x1 = x * v1[0] +x*v2[0] 
y1= y * v1[1]+y* v2[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-d921fff5b2dd> in <module>
#       1 x = np.meshgrid(np.arange(nx),np.arange(nx))
#       2 y = np.meshgrid(np.arange(ny),np.arange(ny))
# ----> 3 x1 = x * v1[0] +x*v2[0]
#       4 y1= y * v1[1]+y* v2[1]
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
y1=x*2.1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-d569c3a38d14> in <module>
# ----> 1 y1=x*2.1
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
X1,Y1=np.meshgrid(x1, y1)
X2,Y2=np.meshgrid(x2, y2)

# %%
Z1=np.ones_like(X1)
Z2=np.ones_like(X2)

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.scatter3D(X1,Y1,Z1,'.')
ax.scatter3D(X2,Y2,Z2,'*')

# %%
np.shape(Z1)
# Out:
# (10, 5)

# %%
np.shape(Z2)
# Out:
# (5, 90)

# %%
np.shape(i2)
# Out:
# (2, 8, 8)
