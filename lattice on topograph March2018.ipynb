# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# Lattice vectors and origin from data. user defined total number of repeatition along each vector

# %%
# values from fft of  F:\Data\4K\March2018\18c30\18c23T0014.SM4
n1=60
n2=60
v1_ini = [-0.462691, -0.209270]
v2_ini = [-0.024471,-0.522391]
ori=[1.1941,0.9856]
# values from lattice of  F:\Data\4K\March2018\18c30\18c23T0014.SM4
# v1_ini = [-0.441022, -0.212932]
# v2_ini = [-0.0141311,-0.525647]
# ori=[1.1941,0.9856]

# %%
rot=0
theta = np.radians(rot)
c, s = np.cos(theta), np.sin(theta)
R = np.array(((c, -s), (s, c)))

# %% [markdown]
# Generating x and y coordinates from index of each point

# %%
v1=R.dot(v1_ini)
v2=R.dot(v2_ini)

# %%
pt_index = np.array(np.meshgrid(np.arange(-n1,n1),np.arange(-n2,n2)))
x= pt_index[0,:,:]* v1[0]+ pt_index[1,:,:]* v2[0]+ori[0]
y= pt_index[0,:,:]* v1[1]+ pt_index[1,:,:]* v2[1]+ori[1]
z=np.ones_like(x)

# %% [markdown]
# Masking x and y values to get lattice in chosen x,y range

# %%
mask_x = np.logical_and(x > 0, x < 28)
mask_y = np.logical_and(y > 0, y < 28)
mask_z = ~np.logical_and(mask_x,mask_y)
z_masked=np.ma.masked_array(z, mask_z)

# %%
# atomic resolution on substrate
data=np.loadtxt('Data/18c23T0014crop.txt')
data_z=data*1e9
data_len=1.87
data_x=np.linspace(0, data_len, num=data_z.shape[0])
data_y=data_x
X,Y=np.meshgrid(data_x,data_y)

# %%
fig = plt.figure()
plt.gca().set_aspect('equal')
ax = plt.axes(projection="3d")
ax.plot_surface(X,Y,data_z,cmap=plt.cm.gray,linewidth=0, antialiased=False, rcount=200, ccount=200 )
ax.scatter3D(x,y,z_masked,'.',s=2,color='red')
ax.view_init(90, 0)
#plt.xlim(0,7)
#plt.ylim(0,7)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-174-572387b90e56>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes(projection="3d")

# %%
# Atomic res on island 
# values from fft of  F:\Data\4K\March2018\18d02\18d02T0004.SM4
n1=100
n2=100
iv1_ini = [0.240420, 0.344074]
iv2_ini = [-0.189432,0.401031]
ori=[1.1941,0.9856]
# values from lattice of   F:\Data\4K\March2018\18d02\18d02T0004.SM4
# iv1_ini = [0.241786, 0.366734]
# iv2_ini = [-0.189115,0.405762]
# ori=[1.1941,0.9856]

# %%
rot=0
theta = np.radians(rot)
c, s = np.cos(theta), np.sin(theta)
R = np.array(((c, -s), (s, c)))
iv1=R.dot(iv1_ini)
iv2=R.dot(iv2_ini)
pt_index = np.array(np.meshgrid(np.arange(-n1,n1),np.arange(-n2,n2)))
ix= pt_index[0,:,:]* iv1[0]+ pt_index[1,:,:]* iv2[0]+ori[0]
iy= pt_index[0,:,:]* iv1[1]+ pt_index[1,:,:]* iv2[1]+ori[1]
iz=np.ones_like(ix)
imask_x = np.logical_and(ix > 0, ix < 28)
imask_y = np.logical_and(iy > 0, iy < 28)
imask_z = ~np.logical_and(imask_x,imask_y)
iz_masked=np.ma.masked_array(iz, imask_z)

# %%
idata=np.loadtxt('data/18d02T0004crop.txt')
idata_z=idata*1e9
idata_len=6.01
idata_x=np.linspace(0, idata_len, num=idata_z.shape[0])
idata_y=idata_x
iX,iY=np.meshgrid(idata_x,idata_y)

# %%
fig = plt.figure()
plt.gca().set_aspect('equal')
ax = plt.axes(projection="3d")
ax.plot_surface(iX,iY,idata_z,cmap=plt.cm.gray,linewidth=0, antialiased=False, rcount=200, ccount=200 )
ax.scatter3D(ix,iy,iz_masked,'.',s=2,color='red')
ax.view_init(90, 0)
#plt.xlim(0,6)
#plt.ylim(0,6)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-186-ed7aff64063b>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes(projection="3d")

# %%
#Moire
mdata=np.loadtxt('data/2minPb0015crop.txt')
mdata_z=mdata*1e9
mdata_len=30.0
mdata_x=np.linspace(0, mdata_len, num=mdata_z.shape[0])
mdata_y=mdata_x
mX,mY=np.meshgrid(mdata_x,mdata_y)

# %%
fig = plt.figure()
plt.gca().set_aspect('equal')
ax = plt.axes(projection="3d")
#ax.plot_surface(mX,mY,mdata_z,cmap=plt.cm.viridis,linewidth=0, antialiased=False, rcount=200, ccount=200 )
ax.scatter3D(x,y,z_masked*30,'.',s=1,color='red')
ax.scatter3D(ix,iy,iz_masked*30,'.',s=1,color='black')
ax.view_init(90, 0)
plt.xlim(5.2,15.8)
plt.ylim(5.2,15.8)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-189-5ee99c8d1575>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes(projection="3d")
# (5.2, 15.8)

# %%
avg_sub_lc=(507.816+522.964+489.735+525.837)/4000

# %%
avg_i_lc=(419.748+443.520+439.266+447.669)/4000

# %%
print(ex_ratio)
print(th_ratio)
# Out:
# 1.1692083718288677
# 1.2202857142857142

# %%
ex_ratio=avg_sub_lc/avg_i_lc
th_ratio=4.271/3.5

# %%
i_lc=(th_ratio/ex_ratio)*3.5

# %%
i_lc
# Out:
# 3.6528989211044824

# %%
np.sqrt(3)*4.271/2
# Out:
# 3.6987944995633373
