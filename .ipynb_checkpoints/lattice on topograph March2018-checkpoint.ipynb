# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# Lattice vectors and origin from data. user defined total number of repeatition along each vector

# %%
n1=10
n2=10
v1_ini = [-2.09907, 1.01428]
v2_ini = [-2.03955,-1.2455]
ori=[0,0]

# %%
rot=0
theta = np.radians(rot)
c, s = np.cos(theta), np.sin(theta)
R = np.array(((c, -s), (s, c)))

# %% [markdown]
# Generating x and y coordinates from index of each point

# %%
v1=R.dot(v1_ini)
v2=R.dot(v2_ini)

# %%
pt_index = np.array(np.meshgrid(np.arange(-n1,n1),np.arange(-n2,n2)))
x= pt_index[0,:,:]* v1[0]+ pt_index[1,:,:]* v2[0]+ori[1]
y= pt_index[0,:,:]* v1[1]+ pt_index[1,:,:]* v2[1]+ori[0]
z=np.ones_like(x)

# %% [markdown]
# Masking x and y values to get lattice in chosen x,y range

# %%
mask_x = np.logical_and(x > 0.2, x < 24.8)
mask_y = np.logical_and(y > 0.2, y < 24.8)
mask_z = ~np.logical_and(mask_x,mask_y)
z_masked=np.ma.masked_array(z, mask_z)

# %%
data=np.loadtxt('18h02T0004_pxl.txt')
data_z=data*1e9

# %%
plt.figure()
plt.imshow(data_z, origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data_x=np.linspace(0, 5.0, num=data_z.shape[0])
data_y=data_x
X,Y=np.meshgrid(data_x,data_y)

# %%
fig = plt.figure()
plt.gca().set_aspect('equal')
ax = plt.axes(projection="3d")
ax.plot_surface(X,Y,data_z,cmap=plt.cm.gray,linewidth=0, antialiased=False, rcount=200, ccount=200 )
ax.scatter3D(x,y,z_masked,'.',s=2,color='red')
ax.view_init(90, 0)
plt.xlim(0,5)
plt.ylim(0,5)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-118-dda1b109b635>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes(projection="3d")
# (0.0, 5.0)

# %%
data=np.loadtxt('18h02T0002_25nm.txt')
data_z=data*1e9
plt.figure()
plt.imshow(data_z, origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data_x=np.linspace(0, 25.0, num=data_z.shape[0])
data_y=data_x
X,Y=np.meshgrid(data_x,data_y)

# %%
fig = plt.figure()
plt.gca().set_aspect('equal')
ax = plt.axes(projection="3d")
ax.plot_surface(X,Y,data_z,cmap=plt.cm.viridis,linewidth=0, antialiased=False, rcount=200, ccount=200 )
ax.scatter3D(x,y,z_masked*3,'.',s=1,color='red')
ax.view_init(90, 0)
plt.xlim(5.2,15.8)
plt.ylim(5.2,15.8)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-135-941b1b9880a1>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes(projection="3d")
# (5.2, 15.8)
